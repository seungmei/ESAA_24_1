# %% [markdown]
# <a href="https://colab.research.google.com/github/seungmei/ESAA_24_1/blob/main/0401%EC%9B%94%EA%B3%BC%EC%A0%9C_%ED%8C%8C%EB%A8%B8%EC%99%84_Ch8_%ED%85%8D%EC%8A%A4%ED%8A%B8%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0401월과제 파머완 Ch8 텍스트분석

# %% [markdown]
# - NLP, National Language Processing
# :인간 언어 이해, 해석 중점.
# e.g. 기계 번역, 자동 질문 해석 답해주는 질의응답 시스템
# - TA, Text Analytics
# :비정형 텍스트에서 의미있는 정보 추출에 더 중점
# e.g. 비즈니스 인텔리전스, 예측 분석
# <= ML

# %% [markdown]
# - Text Classification (or Text Categorization): 문서가 특정 분류 또는 카테고리에 속하는 것을 예측하는 기법. => *지도학습 적용*
# e.g. 신문 기사가 연예/정치/사회/문화 중 어떤 카테고리에 속하는지 자동 분류
# e.g.2. 스팸 메일 검출 프로그램.
# - Sentiment Analysis: 텍스트에서 나타나는 감정/판단/믿음/의견/기분 등의 주관적 요소를 분석하는 기법.
# e.g. 영화, 제품 긍정 또는 리뷰/여론조사 의견 분석 등 다양한 영역에서 활용.
# - Summarization: 텍스트 내에서 중요한 주제나 중심 사상을 추출.
# e.g. Topic Modelling
# - Text Clustering & 유사도 측정: 비슷한 유형의 문서에 대해 군집화 수행 기법. => *비지도학습 적용*

# %% [markdown]
# ## 1. 텍스트 분석 이해
# - 텍스트 분석: 비정형 데이터인 텍스트 분석.
# - 지금까지 ML모델은 주어진 정형 데이터 기반에서 모델을 수립하고 예측을 수행.
#   & ML 알고리즘은 숫자형의 피처 기반 데이터만 입력받을 수 있기 때문에 텍스트를 머신러닝에 적용하기 위해서는 비정형 텍스트 데이터를 어떻게 피처 형태로 추출하고 추출된 피처에 의미 있는 값을 부여하는가 하는 것이 매우 중요 요소.
# - Feature Vectorization or Feature Extraction: 텍스트를 word 기반의 다수의 피처로 추출하고 이 피처에 단어 빈도수와 같은 숫자 값을 부여하면 텍스트는 단어의 조합인 벡터값으로 표현될 수 있는데, 이렇게 텍스트를 변환하는 것.
#   - Bow, Bag of Words
#   - Word2Vec
# **text를 벡터값을 가진 피처로 변환하는 것은 ML 모델을 적용하기 전에 수행해야 할 매우 중요한 요소**

# %% [markdown]
# ### 텍스트 분석 수행 프로세스(ML기반)
# 1. 텍스트 사전 준비작업(텍스트 전처리): 텍스트를 피처로 만들기 전에 클렌징, 대소문자 변경, 특수문자 삭제 / word 등의 토큰화 작업, stop word 제거 작업, stemming/lemmatization 등의 텍스트 정규화 작업 수행
# 2. 피처 벡터화/추출: 사전 준비 작업으로 가공된 텍스트에서 피처 추출 -> 여기에 벡터값 할당
#   - BOW
#     - Count 기반
#     - TF-IDF 기반
#   - Word2Vec
# 3. ML 모델 수립 및 학습/예측/평가: 피처 벡터화된 데이터셋에 ML모델을 적용해 학습/예측 및 평가 수행.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 파이썬 기반의 NLP, 텍스트 분석 패키지
# - NTLK: 방대한 데이터셋, 서브 모듈, 다양한 데이터셋을 지원해 오래전부터 대표적 파이썬 NLP 패키지 but, 수행 성능, 정확도, 신기술, 엔터프라이즈한 기능 지원 등의 측면에서 부족.
# -Gensim, SpaCy: 위의 패키지 보완하면서 실제 업무에서 자주 활용
#   - Gensim: 토픽 모델링 분야에서 가장 두각.
#   - SpaCy: 뛰어난 수행 성능. 최근 가장 주목.

# %% [markdown]
# ## 2. 텍스트 사전 준비 작업(텍스트 전처리) - 텍스트 정규화
# - 텍스트 자체를 바로 피처로 만들기 不可. -> 텍스트 가공 준비 작업 필요.
# - **텍스트 정규화** : ML 알고리즘 or NLP application에 입력 데이터로 사용하기 위해 클렌징, 정제, 토큰화, 어근화 등의 다양한 텍스트 데이터의 사전 작업을 수행하는 것을 의미. *매우 중요한 작업*
#   - Cleansing: 텍스트에서 분석에 방해되는 불필요한 문자, 기호 등을 사전 제거.
#   e.g. HTML, XML 태그 or 특정 기호
#   - Tokenization ; NLTK가 다양한 API 제공
#     - 문장 토큰화: 문서에서 문장을 분리. 각 문장이 가지는 시맨틱적인
#       e.g. ., \n 등 문장의 마지막 기호에 따라 분리.
#     - 단어 토큰화: 문장에서 단어를 분리.
#       e.g. (공백), 콤마, 마침표, 개행문자 등으로 분리.
#       or 정규 표현식을 이용해 다양한 유형으로 토큰화 수행 可
#       - BOW와 같이 단어의 순서가 중요하지 않은 경우, 단어 토큰화만 사용해도 충분.
#   - Filtering / Stop word 제거 / 철자 수정
#   - Stemming
#   - Lemmatization

# %%
#NTLK에서 일반적으로 많이 쓰이는 sent_tokenize를 이용해 문장 토큰화 수행
from nltk import sent_tokenize
import nltk
nltk.download('punkt')

text_sample = 'The Matrix is everywhere its all around us, here even in this room. \
                You can see it out your window or on your television. \
                You feel it when you go to work, or go to church or pay your taxes.'

sentences = sent_tokenize(text=text_sample)
print(type(sentences), len(sentences))
print(sentences)
## sent_tokenize()가 반환하는 것은 각각의 문장으로 구성된 list 객체
# Out:
# <class 'list'> 3
# ['The Matrix is everywhere its all around us, here even in this room.', 'You can see it out your window or on your television.', 'You feel it when you go to work, or go to church or pay your taxes.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#NTLK에서 기본으로 제공하는 word_tokenize()를 이용해 단어 토큰화 수행
from nltk import word_tokenize

sentence = 'The Matrix is everywhere its all around us, here even in this room.'
words = word_tokenize(sentence)
print(type(words), len(words))
print(words)
# Out:
# <class 'list'> 15
# ['The', 'Matrix', 'is', 'everywhere', 'its', 'all', 'around', 'us', ',', 'here', 'even', 'in', 'this', 'room', '.']

# %%
#문서에 대해서 모든 단어 토큰화
from nltk import word_tokenize, sent_tokenize

#여러개의 문장으로 된 입력 데이터를 문장별로 단어 토큰화하게 만드는 함수 생성
def tokenize_text(text):

  #문장별로 분리 토큰
  sentences = sent_tokenize(text)
  #분리된 문장별 단어 토큰화
  word_tokens = [word_tokenize(sentence) for sentence in sentences]
  return word_tokens

#여러 문장에 대해 문장별 단어 토큰화 수행
word_tokens = tokenize_text(text_sample)
print(type(word_tokens), len(word_tokens))
print(word_tokens)
# Out:
# <class 'list'> 3
# [['The', 'Matrix', 'is', 'everywhere', 'its', 'all', 'around', 'us', ',', 'here', 'even', 'in', 'this', 'room', '.'], ['You', 'can', 'see', 'it', 'out', 'your', 'window', 'or', 'on', 'your', 'television', '.'], ['You', 'feel', 'it', 'when', 'you', 'go', 'to', 'work', ',', 'or', 'go', 'to', 'church', 'or', 'pay', 'your', 'taxes', '.']]

# %% [markdown]
# 문장을 단어별로 하나씩 토큰화할 경우 문맥적인 의미가 무시 -> 해결: n-gram
# - n-gram: 연속된 n개의 단어를 하나의 토큰화 단위로 분리해 내는 것.

# %% [markdown]
# ### 스톱 워드 제거
# - Stop word: 분석에 큰 의미가 없는 단어
# e.g. is, the, a, will

# %%
#NLTK에서 제공하는 다양한 언어의 스톱 워드
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print('영어 stop words 개수:', len(nltk.corpus.stopwords.words('english')))
print(nltk.corpus.stopwords.words('english')[:20])
# Out:
# 영어 stop words 개수: 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his']

# %%
import nltk

stopwords = nltk.corpus.stopwords.words('english')
all_tokens = []
#위 예제에서 3개의 문장별로 얻은 word_tokens list에 대해 스톱 워드를 제거하는 반복문
for sentence in word_tokens:
  filtered_words=[]
  #개별 문장별로 토큰화된 문장 list에 대해 스톱 워드를 제거하는 반복문
  for word in sentence:
    #소문자로 모두 변환합니다.
    word = word.lower()
    #토큰화된 개별 단어가 스톱 워드의 단어에 포함되지 않으면 word_tokens()에 추가
    if word not in stopwords:
      filtered_words.append(word)
    all_tokens.append(filtered_words)

print(all_tokens)
## is, this와 같은 스톱워드가 필터링을 통해 제거
# Out:
# [['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',', 'even', 'room', '.'], ['matrix', 'everywhere', 'around', 'us', ',',
# ...

# %% [markdown]
# ### Stemming과 Lemmatization
# - 언어에서 문법적인 요소에 따라 단어가 다양하게 변함.
# e.g. work, worked, works, working
# - Lemmatization이 Stemming보다 정교, 의미론적인 기반에서 단어의 원형 찾음.
# - NTLK
#   - Stemmer 제공 e.g. Porter, Lancaster, Snowball Stemmer
#   - Lemmatization e.g. WordNetLemmatizer

# %%
#NLTK로 Stemming
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()

print(stemmer.stem('working'), stemmer.stem('works'), stemmer.stem('worked'))
print(stemmer.stem('amusing'), stemmer.stem('amuses'), stemmer.stem('amused'))
print(stemmer.stem('happier'), stemmer.stem('happiest'))
print(stemmer.stem('fancier'), stemmer.stem('fanciest'))
# Out:
# work work work
# amus amus amus
# happy happiest
# fant fanciest

# %%
#NLTK로 WordNetLemmatizer를 이용해 Lemmatization을 수행
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')

lemma = WordNetLemmatizer()
print(lemma.lemmatize('amusing', 'v'), lemma.lemmatize('amuses', 'v'), lemma.lemmatize('amused', 'v'))
print(lemma.lemmatize('happier', 'a'), lemma.lemmatize('happiest', 'a'))
print(lemma.lemmatize('fancier', 'a'), lemma.lemmatize('fanciest', 'a'))
# Out:
# amuse amuse amuse
# happy happy
# fancy fancy
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### 3. Bag of Words - BOW
# : 문서가 가지는 모든 words를 문맥이나 순서를 무시하고 일괄적으로 단어에 대해 빈도 값을 부여해 피처 값 추출하는 모델. 문서 내 모든 단어를 한꺼번에 bag안에 넣은 뒤에 흔들어서 섞는다는 의미.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# BOW 모델의 장점: 쉽고 빠른 구축. 단순히 단어의 발생 횟수에 기반하고 있지만, 예상보다 문서의 특징을 잘 나타낼 수 있는 모델이어서 전통적으로 여러 분야에서 활용도가 높다. 하지만, BOW 기반의 NLP 연구는 여러가지 제약에 부딪히고 있다.
# - 단점
#   - 문맥 의미semantic context 반영 부족: 단어의 순서 고려X. 문장 내에서 단어의 문맥적 의미 무시. <- 보완: n_gram(but, 제한적)
#   - 희소 행렬 문제(희소성, 희소 행렬): BOW로 피처 벡터화 수행 시, 희소 행렬 형테의 데이터 세트가 만들어지기 쉬움.

# %% [markdown]
# ### BOW 피처 벡터화
# : 일반적으로 숫자형 피처를 데이터로 입력받아 동작하기 때문에 텍스트와 같은 데이터는 ML 알고리즘에 바로 입력X. 텍스트는 특정 의미를 가지는 숫자형 값인 벡터 값으로 변환되어야...
# e.g. 각 문서의 텍스트 단어 추출-> 피처 할당 -> 단어의 발생 빈도와 같은 값을 피처에 값으로 부여해 각 문서를 이 단어의 피처 발생 빈도 값으로 구성된 벡터로 만드는 기법.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# BOW 피처 벡터화
# - 카운트 기반의 벡터화
#   - 문제: 문서의 특징보다는 언어 특성상 문장에서 자주 사용되는 단어까지 높은 값 부며
# - TF-IDF(Term Frequency - Inverse Document Frequency) 기반의 벡터화
#   : 모든 문서에서 반복적으로 자주 발생하는 단어에 대해서는 패널티 부여. 문서의 개수가 많은 경우 유리.
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 사이킷런의 Count 및 TF-IDF 벡터화 구현: CountVectorizer, TfidfVectorizer
# - CountVectorizer
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 사이킷런의 CountVectorizer 클래스를 이용해 카운트 기반의 피처 여러 개의 문서로 구성된 텍스트의 피처 벡터화
#  - 1) 모든 문자 -> 소문자 변경 등의 전처리
#  - 2) 단어 기준 n_gram_range 반영하여 단어 토큰화
#  - 3) 텍스트 정규화
#  - 4) 파라미터 이용해 토큰화된 단어 피처 추출 => 단어 빈도수 벡터 값 적용
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### BOW 벡터화를 위한 희소 행렬
# : CountVectorizer/TfidVectorizer를 이용해 텍스트를 피처 단위로 벡터화해 변환하고 CSR 형태의 희소 행렬 반환.
# 희소 행렬이란?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 희소 행렬 - COO 형식
# ![image.png](data:image/png;base64,...)

# %%
#Scipy의 sparse 패키지는 희소 행렬 변환을 위한 다양한 모듈 제공
#sparse를 이용해 희소 행렬 변환을 COO 형식으로 수행.
import numpy as np

dense = np.array([[3,0,1], [0,2,0]])

# %%
'''
위의 밀집 행렬을 사이파이의 coo_matrix 클래스 이용하여 COO형식의 희소 행렬로 변환
0이 아닌 데이터를 별도의 배열 데이터로 만들고, 행 위치 배열과 열 위치 배열을 각각 만든 후 coo_matirx() 내에 생성 파라미터로 입력
'''
from scipy import sparse

#0이 아닌 데이터 추출
data = np.array([3,1,2])

#행 위치, 열 위치 각각 배열로 생성
row_pos = np.array([0,0,1])
col_pos = np.array([0,2,1])

#sparse 패키지의 coo_matrix를 이용해 COO형식으로 희소 행렬 생성
sparse_coo = sparse.coo_matrix((data, (row_pos, col_pos)))

# %%
sparse_coo.toarray()
#다시 원래의 데이터 행렬로 추출
# Out:
# array([[3, 0, 1],
#        [0, 2, 0]])

# %% [markdown]
# ### 희소 행렬 - CSR 형식
# - CSR(Compressed Sparse Row) 형식은 COO형식이 행과 열의 위치를 나타내기 위해서 반복적인 위치 데이터를 사용해야 하는 문제점 해결
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
CSR 변환은 사이파이의 csr_matrix 클래스 이용
0이 아닌 데이터 배열과 열 위치 배열, 그리고 행 위치 배열의 고유한 값의 시작 위치배열을 csr_matrix의 생성 배열로
'''
from scipy import sparse

dense = np.array([[0,0,1,0,0,5],
                  [1,4,0,3,2,5],
                  [0,6,0,3,0,0],
                  [2,0,0,0,0,0],
                  [0,0,0,7,0,8],
                  [1,0,0,0,0,0]

])

#0이 아닌 데이터 추출
data2 = np.array([1,5,1,4,3,2,5,6,3,2,7,8,1])

#행 위치와 열 위치를 각각 array로 생성
row_pos = np.array([0,0,1,1,1,1,1,2,2,3,4,4,5])
col_pos = np.array([2,5,0,1,3,4,5,1,3,0,3,5,0])

#COO 형식으로 변환
sparse_coo = sparse.coo_matrix((data2, (row_pos, col_pos)))

#행 위치 배열의 고유한 값의 시작 위치 인덱스를 배열로 생성
row_pos_ind = np.array([0,2,7,9,10,12,13])

#CSR 형식으로 변환
sparse_csr = sparse.csr_matrix((data2, col_pos, row_pos_ind))

print('COO 변환된 데이터가 제대로 되었는지 다시 Dense로 출력 확인')
print(sparse_coo.toarray())
print('CSR 변환된 데이터가 제대로 되었는지 다시 Dense로 출력 확인')
print(sparse_csr.toarray())
# Out:
# COO 변환된 데이터가 제대로 되었는지 다시 Dense로 출력 확인
# [[0 0 1 0 0 5]
#  [1 4 0 3 2 5]
#  [0 6 0 3 0 0]
#  [2 0 0 0 0 0]
#  [0 0 0 7 0 8]
#  [1 0 0 0 0 0]]
# CSR 변환된 데이터가 제대로 되었는지 다시 Dense로 출력 확인
# [[0 0 1 0 0 5]
#  [1 4 0 3 2 5]
#  [0 6 0 3 0 0]
#  [2 0 0 0 0 0]
#  [0 0 0 7 0 8]
#  [1 0 0 0 0 0]]

# %%
#실제 사용시에는 밀집 행렬을 생성 파라미터로 입력하면 COO나 CSR 희소 행렬로 생성
dense3= np.array([[0,0,1,0,0,5],
                  [1,4,0,3,2,5],
                  [0,6,0,3,0,0],
                  [2,0,0,0,0,0],
                  [0,0,0,7,0,8],
                  [1,0,0,0,0,0]

])
coo = sparse.coo_matrix(dense3)
csr = sparse.csr_matrix(dense3)
